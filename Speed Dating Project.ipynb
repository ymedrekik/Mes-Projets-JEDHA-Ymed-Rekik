# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_rows = 1000 #handy for showing truncated results
pd.set_option('display.max_column', 195)
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('Speed Dating Data.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#     iid  wave  gender   age      field  field_cd undergra mn_sat tuition  \
# 0     1     1  Female  21.0        Law       1.0      NaN    NaN     NaN
# 10    2     1  Female  24.0        law       1.0      NaN    NaN     NaN
# 20    3     1  Female  25.0  Economics       2.0      NaN    NaN     NaN
# 30    4     1  Female  23.0        Law       1.0      NaN    NaN     NaN
# 40    5     1  Female  21.0        Law       1.0      NaN    NaN     NaN
#
#      race  imprace  imprelig             from zipcode     income   goal  date  \
# 0   Asian      2.0       4.0          Chicago  60,521  69,487.00   Meet   7.0
# 10  White      2.0       5.0          Alabama  35,223  65,929.00    Fun   5.0
# 20  White      8.0       4.0      Connecticut   6,268        NaN  Other   3.0
# 30  White      1.0       1.0            Texas  77,096  37,754.00    Fun   5.0
# 40  White      8.0       1.0  Bowdoin College  94,022  86,340.00   Meet   4.0
#
# ...

# %%
df.describe()
# Out:
#                iid           id       gender          idg       condtn  \
# count  8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# mean    283.675937     8.960248     0.500597    17.327166     1.828837
# std     158.583367     5.491329     0.500029    10.940735     0.376673
# min       1.000000     1.000000     0.000000     1.000000     1.000000
# 25%     154.000000     4.000000     0.000000     8.000000     2.000000
# 50%     281.000000     8.000000     1.000000    16.000000     2.000000
# 75%     407.000000    13.000000     1.000000    26.000000     2.000000
# max     552.000000    22.000000     1.000000    44.000000     2.000000
#
#               wave        round     position     positin1        order  ...  \
# count  8378.000000  8378.000000  8378.000000  6532.000000  8378.000000  ...
# mean     11.350919    16.872046     9.042731     9.295775     8.927668  ...
# std       5.995903     4.358458     5.514939     5.650199     5.477009  ...
# ...

# %%
df.isnull().sum()
# Out:
# iid            0
# id             1
# gender         0
# idg            0
# condtn         0
# wave           0
# round          0
# position       0
# positin1    1846
# order          0
# partner        0
# pid           10
# match          0
# int_corr     158
# samerace       0
# age_o        104
# race_o        73
# pf_o_att      89
# pf_o_sin      89
# pf_o_int      89
# pf_o_fun      98
# pf_o_amb     107
# pf_o_sha     129
# dec_o          0
# attr_o       212
# sinc_o       287
# intel_o      306
# fun_o        360
# amb_o        722
# shar_o      1076
# like_o       250
# prob_o       318
# met_o        385
# age           95
# field         63
# field_cd      82
# undergra    3464
# mn_sat      5245
# tuition     4795
# race          63
# imprace       79
# imprelig      79
# from          79
# zipcode     1064
# income      4099
# goal          79
# date          97
# go_out        79
# career        89
# career_c     138
# sports        79
# tvsports      79
# ...

# %%
plt.figure(figsize=(14,6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# Group Columns info per category to reduce the noise.
#
# Also the dataset would be on 8378 persons with multiple rounds as the wave indicate.
#
# For the sake of the analysis,
# There is a need to create a second DataFrame with only the unique entries, giving us the real number of participants that is equal to 551.

# %%
interests = ['gender', 'age', 'field', 'field_cd', 'undergra',
       'mn_sat', 'tuition', 'race', 'imprace', 'imprelig', 'from',
       'zipcode', 'income', 'goal', 'date', 'go_out', 'career',
       'career_c', 'sports', 'tvsports', 'exercise', 'dining', 'museums',
       'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater',
       'movies', 'concerts', 'music', 'shopping', 'yoga', 'exphappy',
       'expnum','match_es']
match_decision = ['match','dec',
       'attr', 'sinc', 'intel', 'fun', 'amb', 'shar', 'like', 'prob',
       'met']
other1 = ['satis_2', 'length', 'numdat_2']
other2 = ['you_call', 'them_cal', 'date_3', 'numdat_3',
       'num_in_3']

# %%
df = df[['iid', 'wave'] + interests + other1 + other2].drop_duplicates().copy()
df.head()
# Out:
#     iid  wave  gender   age      field  field_cd undergra mn_sat tuition  \
# 0     1     1       0  21.0        Law       1.0      NaN    NaN     NaN
# 10    2     1       0  24.0        law       1.0      NaN    NaN     NaN
# 20    3     1       0  25.0  Economics       2.0      NaN    NaN     NaN
# 30    4     1       0  23.0        Law       1.0      NaN    NaN     NaN
# 40    5     1       0  21.0        Law       1.0      NaN    NaN     NaN
#
#     race  ...  expnum  match_es satis_2 length numdat_2  you_call  them_cal  \
# 0    4.0  ...     2.0       4.0     6.0    2.0      1.0       1.0       1.0
# 10   2.0  ...     5.0       3.0     5.0    2.0      NaN       0.0       0.0
# 20   2.0  ...     2.0       NaN     NaN    NaN      NaN       NaN       NaN
# 30   2.0  ...     2.0       2.0     4.0    3.0      2.0       0.0       0.0
# 40   2.0  ...    10.0       NaN     7.0    2.0      2.0       0.0       0.0
#
#     date_3 numdat_3  num_in_3
# 0      0.0      NaN       NaN
# ...

# %% [markdown]
# Noise of NAN reduce but still noisy!

# %%
plt.figure(figsize=(14,6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df['gender'] = df.gender.map({1 : 'Male', 0 : 'Female'}).fillna(df.gender)
df['gender'] = df.gender.map({1 : 'Male', 0 : 'Female'}).fillna(df.gender)
df.gender.value_counts(dropna=False)
# Out:
# Male      277
# Female    274
# Name: gender, dtype: int64

# %%
df[['gender', 'age']].groupby('gender').agg(['mean', 'median', 'min', 'max', 'count'])
# Out:
#               age
#              mean median   min   max count
# gender
# Female  26.126394   26.0  19.0  55.0   269
# Male    26.587591   27.0  18.0  42.0   274

# %%
ax = df.age.hist(bins=30, figsize=(12,8))
ax.set_title('Age Distribution', fontsize=15)
ax.set_xlabel('Age',fontsize=12)
ax.set_ylabel('Count', fontsize=12)
ax.grid(False)

# %%
df['goal'] = df.goal.map({1: 'Fun', 2: 'Meet', 3: 'Date', 
                          4: 'Relationship', 5: 'IdidIt', 6: 'Other'}).fillna(df.goal)
df.goal.value_counts(dropna=False)
# Out:
# Fun             228
# Meet            189
# Date             40
# IdidIt           35
# Other            30
# Relationship     22
# NaN               7
# Name: goal, dtype: int64

# %%
df_gender = df[['gender', 'goal']].groupby(['goal', 'gender']).size().unstack()
ax = df_gender.plot(kind='bar', figsize=(12,6), ylim=(0,130))
ax.set_xticklabels(ax.get_xticklabels(), fontsize=12, rotation='horizontal')

ax.set_title('Declared goal for the evening, by gender', fontsize=18)

for i in ax.patches:
    ax.text(i.get_x()+.07, i.get_height()+3, \
            str(round((i.get_height()), 1)), fontsize=10)

# %% [markdown]
# Interests Correlation?

# %%
interests = ['sports', 'tvsports', 'exercise', 'dining', 'museums',
       'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater',
       'movies', 'concerts', 'music', 'shopping', 'yoga']

# %%
correl = df[interests].corr()
plt.figure(figsize=(16,8))
ax = sns.heatmap(correl, annot=True, cmap='viridis')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title('Correlation between interests', fontsize=18)
# Out:
# Text(0.5, 1, 'Correlation between interests')

# %% [markdown]
# Attraction between Males and Females by Interests

# %%
correl_m = df[df.gender=='Male'][interests].corr()
correl_f = df[df.gender=='Female'][interests].corr()

fig, ax= plt.subplots(1,2, figsize=(25, 12))
sns.heatmap(correl_m, cmap='viridis',annot=True, ax=ax[0])
sns.heatmap(correl_f, cmap='viridis',annot=True, ax=ax[1])

ax[0].set_title('Males', fontsize=12)
ax[1].set_title('Females', fontsize=10)
# Out:
# Text(0.5, 1, 'Females')

# %% [markdown]
# Interest By Roots

# %%
df['race'] = df.race.map({1: 'Black', 2: 'White', 3: 'Hispanic', 
                          4: 'Asian', 6: 'Other'}).fillna(df.race)

df.race.value_counts(dropna=False)
# Out:
# White       304
# Asian       136
# Hispanic     42
# Other        37
# Black        26
# NaN           6
# Name: race, dtype: int64

# %%
g = sns.FacetGrid(df, col='race')
g.map(plt.hist, 'imprace', bins=12)
axes = g.axes.flatten()
axes[0].set_title("Asian")
axes[1].set_title("White")
axes[2].set_title("Other")
axes[3].set_title("Hispanic")
axes[4].set_title("Black")
g.set_xlabels('', fontsize=1)
plt.subplots_adjust(top=0.8)
g.fig.suptitle('How important is the Roots, by Roots', fontsize=18)
g.add_legend()

# %%
ax = df[['race', 'imprace']].groupby('race').mean().plot(kind='bar', figsize=(18,10), legend=False,
                                               title='Average importance of Roots, by Roots',
                                                   ylim=(2,5), color='rgbmc')
ax.set_xticklabels(ax.get_xticklabels(), fontsize=15, rotation='horizontal')
ax.set_xlabel('',fontsize=1)

for i in ax.patches:
    ax.text(i.get_x()+.2, i.get_height()+.05, \
            str(round((i.get_height()), 1)), fontsize=15)

# %%
ax = df.imprace.hist(bins=20,color='green', figsize=(16,8))
ax.set_title('How important is the roots', fontsize=16)
ax.set_xlabel('Importance',fontsize=12)
ax.set_ylabel('Count', fontsize=14)
ax.grid(False)
